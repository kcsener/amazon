# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as BS
import requests
import time
from random import randint
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'}

# %%
# DELAY FUNCTION to avoid from being blocked
def delay():
    delays = randint(5, 21)
    delay = np.random.choice(delays)
    return time.sleep(delay)

#DATA ACQUISITION FUNCTION for More-Sellers Products
def data_acquisition(url_for_func):
    print('Collecting data from table page')
    price_list = []
    condition_list = []
    seller_list = []
    
    #for page no:1
    url = url_for_func[:51] + 'ref=olp_page_1?ie=UTF8&f_all=true&startIndex=00'
    print('Page number: 1')
    response=requests.get(url, headers=headers)
    delay()
    soup=BS(response.content, features="lxml") 
    child_list = [3,5,7,9,12,14,16,18,20,22]
    for i in child_list:
        try:
            price_list.append(soup.select('.olpOffer:nth-child({}) .olpOfferPrice'.format(str(i)))[0].get_text().strip())
        except:
            price_list.append(np.nan)  
        try:
            condition_list.append(soup.select('.olpOffer:nth-child({}) .olpCondition'.format(str(i)))[0].get_text().strip())
        except:
            condition_list.append(np.nan)
        try:
            seller_list.append(soup.select('.olpOffer:nth-child({}) .a-text-bold a'.format(str(i)))[0].get_text().strip())
        except:
            seller_list.append(np.nan)
            
    #for page no>1  
    for i in range(2,100):      
        
        url = url_for_func[:51] + 'ref=olp_page_{}?ie=UTF8&f_all=true&startIndex={}0'.format(str(i), str(i-1))
        response=requests.get(url, headers=headers)
        delay()
        soup=BS(response.content, features="lxml") 
        table_content = soup.select('.a-padding-small')[0].get_text().strip()
        
        url_previous = url_for_func[:51] + 'ref=olp_page_{}?ie=UTF8&f_all=true&startIndex={}0'.format(str(i-1), str(i-2))
        response_previous=requests.get(url_previous, headers=headers)
        delay()
        soup_previous=BS(response_previous.content, features="lxml") 
        table_content_previous = soup_previous.select('.a-padding-small')[0].get_text().strip()
        
        print('Page number: ', i)
        if table_content != table_content_previous:
            print('the page table contents are not same')
            
            child_list = [3,5,7,9,12,14,16,18,20,22]
            for i in child_list:
                try:
                    price_list.append(soup.select('.olpOffer:nth-child({}) .olpOfferPrice'.format(str(i)))[0].get_text().strip())
                except:
                    price_list.append(np.nan)  
                try:
                    condition_list.append(soup.select('.olpOffer:nth-child({}) .olpCondition'.format(str(i)))[0].get_text().strip())
                except:
                    condition_list.append(np.nan)
                try:
                    seller_list.append(soup.select('.olpOffer:nth-child({}) .a-text-bold a'.format(str(i)))[0].get_text().strip())
                except:
                    seller_list.append(np.nan)
        else:
            print('The page table contents are same. Go to next product..')
            break
            
    df = pd.DataFrame(list(zip(price_list, condition_list, seller_list)), columns= ['Price', 'Condition', 'Seller']) 
    
    try:
        product_name=soup.select("#olpProductDetails .a-spacing-none")[0].get_text().strip()
    except:
        product_name = np.nan
    df['ProductName'] = product_name  
    
    try:
        brand = soup.select('#olpProductByline')[0].get_text().strip()
    except:
        brand = np.nan
    df['Brand'] = brand
    
    try:
        Feature1Name = soup.select('.a-spacing-micro:nth-child(1) .a-size-base:nth-child(1)')[0].get_text().strip()
        Feature1 = soup.select('.a-spacing-micro:nth-child(1) .a-text-bold')[0].get_text().strip()
    except:
        Feature1Name = np.nan
        Feature1 = np.nan
    df['Feature1Name'] = Feature1Name
    df['Feature1'] = Feature1
    
    try:
        Feature2Name = soup.select('.a-spacing-small+ .a-spacing-micro .a-size-base:nth-child(1)')[0].get_text().strip()
        Feature2 = soup.select('.a-spacing-small+ .a-spacing-micro .a-text-bold')[0].get_text().strip()
    except:
        Feature2Name = np.nan
        Feature2 = np.nan
    df['Feature2Name'] = Feature2Name
    df['Feature2'] = Feature2  
    
    return df

# %%
links = {'https://www.amazon.com/s?k=nintendo+switch+console&page=':20,
         'https://www.amazon.com/s?k=robot+vacuum+cleaner&page=':20,
         'https://www.amazon.com/s?k=apple+iphone+11+pro%2C+256gb&rh=p_89%3AApple&dc&page=':4,
         'https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=':13
        }
df_main = pd.DataFrame(columns = ['Price', 'Condition', 'Seller', 'ProductName', 'Brand',
                                 'Feature1Name', 'Feature1', 'Feature2Name', 'Feature2'])
for link in links.keys():
    for pn in range(1, links[link]+1):
        url_main = link + str(pn)
        print(url_main)
        response_main=requests.get(url_main, headers=headers)
        delay()
        soup_main=BS(response_main.content, features="lxml")
        a = soup_main.select('a.a-link-normal.a-text-normal')
        url_link_list = []
        for i in a:
            url_link = 'https://www.amazon.com' + i['href']
            url_link_list.append(url_link)
        url_link_list = list(dict.fromkeys(url_link_list))
        for url_link in url_link_list:
            print(url_link, 'url_link')
            try:
                response_link=requests.get(url_link, headers=headers)
                delay()
                soup_link=BS(response_link.content, features="lxml")
                source_codes = ['a#buybox-see-all-buying-choices-announce.a-button-text', 
                                '#olpDiv a', 
                                'a.a-touch-link.a-box.olp-touch-link', 
                                '#availability a', 
                                '#olpLinkWidget_feature_div .a-box-inner',
                               '#olpLinkWidget_feature_div .a-color-price',
                               '#olp-upd-new-used .a-link-normal',
                               '#alternativeOfferEligibilityMessaging_feature_div a']
                url_link_in_link_list = []
                print('Searching source codes...')
                for s in source_codes:
                    try:
                        b = soup_link.select(s)
                        if b != []:
                            delay()
                            for i in b:
                                url_link_in_link = 'https://www.amazon.com' + i['href']
                                url_link_in_link_list.append(url_link_in_link) 
                            print('full link')
                        else:
                            print('empty link')
                    except:
                        pass
                print(url_link_in_link_list, 'url_link_in_link_list')
                if len(url_link_in_link_list) != 0:
                    url_link_in_link = url_link_in_link_list[0]
                    print(url_link_in_link, 'url_link_in_link')
                    try:
                        response_link_in_link=requests.get(url_link_in_link, headers=headers)
                        delay()
                        soup_link_in_link=BS(response_link_in_link.content, features="lxml")
                        response_link_in_link_in_link=requests.get(url_link_in_link, headers=headers)
                        delay()
                        soup=BS(response_link_in_link_in_link.content, features="lxml")
                        print('there are links in url_link_in_link')
                        #for product specifications:
                        q = soup.select('ul.a-unordered-list.a-nostyle.a-button-list.a-declarative.a-button-toggle-group.a-horizontal.a-spacing-small')
                        #first feature 
                        list_f1 = []
                        for i in q[0]:
                            for j in i:
                                for k in j:
                                    for l in k:
                                        for p in l:
                                                list_f1.append(p)
                        url_feature_1 = []
                        for i in list_f1:
                            try:
                                url_feature_1.append(i['href'])
                            except:
                                pass
                        for i in url_feature_1:
                            url_detail = 'https://www.amazon.com' + i
                            try:
                                response_detail=requests.get(url_detail, headers=headers)
                                delay()
                                soup_detay=BS(response_detail.content, features="lxml")
                                q = soup_detay.select('ul.a-unordered-list.a-nostyle.a-button-list.a-declarative.a-button-toggle-group.a-horizontal.a-spacing-small')
                                #second feature
                                list_f2 = []
                                for n in q[1]:
                                    for j in n:
                                        for k in j:
                                            for l in k:
                                                for p in l:
                                                        list_f2.append(p)
                                                        url_feature_2 = []
                                                        for i in list_f2:
                                                            try:
                                                                url_feature_2.append(i['href'])
                                                            except:
                                                                pass
                                for i in url_feature_2:
                                    url_in_detail = 'https://www.amazon.com' + i
                                    url_for_func = url_in_detail

                                    df_main = df_main.append(data_acquisition(url_for_func))
                                    print(url_in_detail[:51], 'url_double_feature')
                            except:
                                url_for_func = url_detail
                                df_main = df_main.append(data_acquisition(url_for_func))
                                print(url_detail[:51], 'url_single_feature')
                    except:
                        url_for_func = url_link_in_link
                        df_main = df_main.append(data_acquisition(url_for_func))
                        print(url_link_in_link[:51], 'url_no_feature')
                else:
                    #url_for_func = url_link
                    #df_main = df_main.append(data_acq_for_one_seller(url_for_func))
                    print('one seller')
            except:
                print('no product link')
# Out:
# https://www.amazon.com/s?k=nintendo+switch+console&page=0
# https://www.amazon.com/Nintendo-Switch-Neon-Blue-Joy%E2%80%91/dp/B07VGRJDFY/ref=sr_1_1?keywords=nintendo+switch+console&qid=1583656677&sr=8-1 url_link
# Searching source codes...
# full link
# empty link
# empty link
# full link
# empty link
# empty link
# full link
# empty link
# ['https://www.amazon.com/gp/offer-listing/B07VGRJDFY/ref=dp_olp_all_mbc?ie=UTF8&condition=all', 'https://www.amazon.com/gp/offer-listing/B07VGRJDFY/ref=dp_olp_0?ie=UTF8&condition=all&qid=1583656677&sr=8-1', 'https://www.amazon.com/gp/offer-listing/B07VGRJDFY/ref=dp_olp_all_mbc?ie=UTF8&condition=all'] url_link_in_link_list
# https://www.amazon.com/gp/offer-listing/B07VGRJDFY/ref=dp_olp_all_mbc?ie=UTF8&condition=all url_link_in_link
# there are links in url_link_in_link
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07VJRZ62R/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07VGRJDFY/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YBVW7RH/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YBVJRD7/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YMJ4XBP/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YMPLCXM/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YMM3RHZ/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YMR6NB8/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# https://www.amazon.com/Nintendo-Switch-Gray-Mario-Deluxe-Download/dp/B07YZQSC5Y/ref=sr_1_2?keywords=nintendo+switch+console&qid=1583656677&sr=8-2 url_link
# Searching source codes...
# empty link
# full link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# ['https://www.amazon.com/gp/offer-listing/B07YZQSC5Y/ref=dp_olp_all_mbc?ie=UTF8&condition=all'] url_link_in_link_list
# https://www.amazon.com/gp/offer-listing/B07YZQSC5Y/ref=dp_olp_all_mbc?ie=UTF8&condition=all url_link_in_link
# there are links in url_link_in_link
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# the page table contents are not same
# Page number:  4
# the page table contents are not same
# Page number:  5
# the page table contents are not same
# Page number:  6
# the page table contents are not same
# Page number:  7
# the page table contents are not same
# Page number:  8
# the page table contents are not same
# Page number:  9
# the page table contents are not same
# Page number:  10
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YZQSC5Y/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B0825P21NF/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# the page table contents are not same
# Page number:  4
# the page table contents are not same
# Page number:  5
# the page table contents are not same
# Page number:  6
# the page table contents are not same
# Collecting data from table page
# Page number: 1
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# no product link
# https://www.amazon.com/Nintendo-Switch-Neon-Mario-Deluxe-Download/dp/B07YZQ9QMD/ref=sr_1_2?keywords=nintendo+switch+console&qid=1583656677&sr=8-2 url_link
# Searching source codes...
# empty link
# full link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# ['https://www.amazon.com/gp/offer-listing/B07YZQ9QMD/ref=dp_olp_all_mbc?ie=UTF8&condition=all'] url_link_in_link_list
# https://www.amazon.com/gp/offer-listing/B07YZQ9QMD/ref=dp_olp_all_mbc?ie=UTF8&condition=all url_link_in_link
# there are links in url_link_in_link
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# the page table contents are not same
# Page number:  4
# the page table contents are not same
# Page number:  5
# the page table contents are not same
# Page number:  6
# the page table contents are not same
# Page number:  7
# the page table contents are not same
# Page number:  8
# the page table contents are not same
# Page number:  9
# the page table contents are not same
# Page number:  10
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YZQSC5Y/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B0825P21NF/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# the page table contents are not same
# Page number:  4
# the page table contents are not same
# Page number:  5
# the page table contents are not same
# Page number:  6
# the page table contents are not same
# Page number:  7
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YZQ9QMD/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B0825P21NF/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B0825P21NF/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B0825P21NF/ url_double_feature
# https://www.amazon.com/Nintendo-Switch-Gray-Joy%E2%80%91-HAC-001/dp/B07VJRZ62R/ref=sxin_2_ac_d_rm?ac_md=0-0-bmludGVuZG8gc3dpdGNoIGNvbnNvbGU%3D-ac_d_rm&cv_ct_cx=nintendo+switch+console&keywords=nintendo+switch+console&pd_rd_i=B07VJRZ62R&pd_rd_r=3e77076e-686c-4f50-bfee-40167807f345&pd_rd_w=vPvyc&pd_rd_wg=crojo&pf_rd_p=ec111f65-4a46-499c-be78-f47997212bd0&pf_rd_r=61ZWQD6YQJB9JQWXDHQQ&psc=1&qid=1583656677 url_link
# Searching source codes...
# full link
# empty link
# empty link
# full link
# empty link
# empty link
# full link
# empty link
# ['https://www.amazon.com/gp/offer-listing/B07VJRZ62R/ref=dp_olp_all_mbc?ie=UTF8&condition=all', 'https://www.amazon.com/gp/offer-listing/B07VJRZ62R/ref=dp_olp_0?ie=UTF8&condition=all&qid=1583656677', 'https://www.amazon.com/gp/offer-listing/B07VJRZ62R/ref=dp_olp_all_mbc?ie=UTF8&condition=all'] url_link_in_link_list
# https://www.amazon.com/gp/offer-listing/B07VJRZ62R/ref=dp_olp_all_mbc?ie=UTF8&condition=all url_link_in_link
# there are links in url_link_in_link
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07VJRZ62R/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# the page table contents are not same
# Page number:  4
# the page table contents are not same
# Page number:  5
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07VGRJDFY/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YBVW7RH/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YBVJRD7/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YMJ4XBP/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YMPLCXM/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YMM3RHZ/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07YMR6NB8/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B07XLGBYM3/ url_double_feature
# https://www.amazon.com/Mario-Kart-8-Deluxe-Nintendo-Switch/dp/B01N1037CV/ref=sxin_2_ac_d_rm?ac_md=1-1-bmludGVuZG8gc3dpdGNoIGdhbWVz-ac_d_rm&cv_ct_cx=nintendo+switch+console&keywords=nintendo+switch+console&pd_rd_i=B01N1037CV&pd_rd_r=3e77076e-686c-4f50-bfee-40167807f345&pd_rd_w=vPvyc&pd_rd_wg=crojo&pf_rd_p=ec111f65-4a46-499c-be78-f47997212bd0&pf_rd_r=61ZWQD6YQJB9JQWXDHQQ&psc=1&qid=1583656677 url_link
# Searching source codes...
# empty link
# full link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# ['https://www.amazon.com/gp/offer-listing/B01N1037CV/ref=dp_olp_all_mbc?ie=UTF8&condition=all'] url_link_in_link_list
# https://www.amazon.com/gp/offer-listing/B01N1037CV/ref=dp_olp_all_mbc?ie=UTF8&condition=all url_link_in_link
# there are links in url_link_in_link
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# the page table contents are not same
# Page number:  4
# the page table contents are not same
# Page number:  5
# the page table contents are not same
# Page number:  6
# the page table contents are not same
# Page number:  7
# the page table contents are not same
# Page number:  8
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B01N1037CV/ url_double_feature
# Collecting data from table page
# Page number: 1
# Page number:  2
# The page table contents are same. Go to next product..
# https://www.amazon.com/gp/offer-listing/B06ZYWRMQK/ url_double_feature
# Collecting data from table page
# Page number: 1
# Collecting data from table page
# Page number: 1
# Page number:  2
# the page table contents are not same
# Page number:  3
# the page table contents are not same
# Page number:  4
# the page table contents are not same
# Page number:  5
# the page table contents are not same
# no product link
# https://www.amazon.com/Nintendo-Joy-Neon-Pink-Green-switch/dp/B078GZM4H8/ref=sxin_2_ac_d_rm?ac_md=2-2-bmludGVuZG8gc3dpdGNoIGNvbnRyb2xsZXI%3D-ac_d_rm&cv_ct_cx=nintendo+switch+console&keywords=nintendo+switch+console&pd_rd_i=B078GZM4H8&pd_rd_r=3e77076e-686c-4f50-bfee-40167807f345&pd_rd_w=vPvyc&pd_rd_wg=crojo&pf_rd_p=ec111f65-4a46-499c-be78-f47997212bd0&pf_rd_r=61ZWQD6YQJB9JQWXDHQQ&psc=1&qid=1583656677 url_link
# Searching source codes...
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# [] url_link_in_link_list
# one seller
# https://www.amazon.com/Nintendo-Entertainment-System-NES-Classic/dp/B01IFJBQ1E/ref=sxin_2_ac_d_rm?ac_md=3-3-bmludGVuZG8%3D-ac_d_rm&cv_ct_cx=nintendo+switch+console&keywords=nintendo+switch+console&pd_rd_i=B01IFJBQ1E&pd_rd_r=3e77076e-686c-4f50-bfee-40167807f345&pd_rd_w=vPvyc&pd_rd_wg=crojo&pf_rd_p=ec111f65-4a46-499c-be78-f47997212bd0&pf_rd_r=61ZWQD6YQJB9JQWXDHQQ&psc=1&qid=1583656677 url_link
# Searching source codes...
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# [] url_link_in_link_list
# one seller
# https://www.amazon.com/
_link
# Searching source codes...
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# [] url_link_in_link_list
# one seller
# https://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_btf_aps_sr_pg1_4?ie=UTF8&adId=A05425773GILZ3MUP6SJD&url=%2FHandle-Bracket-Nintendo-Adjustable-Console%2Fdp%2FB082PLVDKR%2Fref%3Dsr_1_22_sspa%3Fkeywords%3Dnintendo%2Bswitch%2Bconsole%26qid%3D1583656677%26sr%3D8-22-spons%26psc%3D1&qualifier=1583656676&id=4638440745297911&widgetName=sp_btf url_link
# Searching source codes...
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# empty link
# [] url_link_in_link_list
# one seller
# https://www.amazon.comhttps://aax-us-east.amazon-adsystem.com/x/c/QhOwkJxBLItCuAdBiFkneLIAAAFwuUsveAEAAAH2AcQBJ48/https://www.amazon.com/dp/B07VHBDJ7K?pd_rd_w=1SEE9&pf_rd_p=40f58d87-76a1-42d8-86c6-e1c4c3b47384&pd_rd_wg=PzkVm&pf_rd_r=61ZWQD6YQJB9JQWXDHQQ&pd_rd_r=e55063d2-1eb3-4e67-a863-75d23520a19c url_link
# no product link
# https://www.amazon.com/s?k=nintendo+switch+console&page=1
# https://www.amazon.com/s?k=nintendo+switch+console&page=2
# https://www.amazon.com/s?k=nintendo+switch+console&page=3
# https://www.amazon.com/s?k=nintendo+switch+console&page=4
# https://www.amazon.com/s?k=nintendo+switch+console&page=5
# https://www.amazon.com/s?k=nintendo+switch+console&page=6
# https://www.amazon.com/s?k=nintendo+switch+console&page=7
# https://www.amazon.com/s?k=nintendo+switch+console&page=8
# https://www.amazon.com/s?k=nintendo+switch+console&page=9
# https://www.amazon.com/s?k=nintendo+switch+console&page=10
# https://www.amazon.com/s?k=nintendo+switch+console&page=11
# https://www.amazon.com/s?k=nintendo+switch+console&page=12
# https://www.amazon.com/s?k=nintendo+switch+console&page=13
# https://www.amazon.com/s?k=nintendo+switch+console&page=14
# https://www.amazon.com/s?k=nintendo+switch+console&page=15
# https://www.amazon.com/s?k=nintendo+switch+console&page=16
# https://www.amazon.com/s?k=nintendo+switch+console&page=17
# https://www.amazon.com/s?k=nintendo+switch+console&page=18
# https://www.amazon.com/s?k=nintendo+switch+console&page=19
# https://www.amazon.com/s?k=nintendo+switch+console&page=20
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=0
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=1
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=2
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=3
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=4
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=5
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=6
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=7
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=8
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=9
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=10
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=11
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=12
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=13
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=14
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=15
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=16
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=17
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=18
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=19
# https://www.amazon.com/s?k=robot+vacuum+cleaner&page=20
# https://www.amazon.com/s?k=apple+iphone+11+pro%2C+256gb&rh=p_89%3AApple&dc&page=0
# https://www.amazon.com/s?k=apple+iphone+11+pro%2C+256gb&rh=p_89%3AApple&dc&page=1
# https://www.amazon.com/s?k=apple+iphone+11+pro%2C+256gb&rh=p_89%3AApple&dc&page=2
# https://www.amazon.com/s?k=apple+iphone+11+pro%2C+256gb&rh=p_89%3AApple&dc&page=3
# https://www.amazon.com/s?k=apple+iphone+11+pro%2C+256gb&rh=p_89%3AApple&dc&page=4
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=0
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=1
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=2
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=3
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=4
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=5
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=6
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=7
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=8
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=9
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=10
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=11
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=12
# https://www.amazon.com/s?k=aorus+geforce+rtx+2070&page=13

# %%
df_main.to_csv(r'C:\Users\Asus\Desktop\df_main080320.csv')

# %%
df = pd.read_csv('C:/Users/Asus/Desktop/df_main080320.csv')

# %%
df = df.dropna()
df = df.drop_duplicates()
df[df['Condition'] == 'New']
df
# Out:
#      Unnamed: 0    Price                   Condition  \
# 0             0  $299.99  Used\n         - Very Good
# 1             1  $328.88   Used\n         - Like New
# 2             2  $341.69                         New
# 3             3  $399.99                         New
# 4             4  $279.00  Used\n         - Very Good
# 5             5  $291.00                         New
# 7             7  $312.49                         New
# 8             8  $334.20                         New
# 9             9  $339.00                         New
# 10           10  $339.00                         New
# 11           11  $339.99                         New
# 12           12  $349.95                         New
# 13           13  $359.99                         New
# 14           14  $363.02                         New
# 15           15  $372.85                         New
# 16           16  $389.95       Used\n         - Good
# 17           17  $399.00                         New
# 18           18  $448.15                         New
# 20            0  $334.99                         New
# 21            1  $348.95                         New
# 22            2  $379.99                         New
# 23            3  $419.99                         New
# 25            5  $309.99   Used\n         - Like New
# 26            6  $327.28                         New
# 27            7  $332.17                         New
# 28            8  $335.00                         New
# 29            9  $339.99                         New
# 30           10  $342.53                         New
# 31           11  $349.00                         New
# 32           12  $349.95                         New
# ..          ...      ...                         ...
# 705          35   $62.43                         New
# 706          36   $62.92                         New
# 707          37   $62.99                         New
# 708          38   $63.90                         New
# 709          39   $64.00                         New
# 710          40   $66.20                         New
# 711          41   $66.20                         New
# 712          42   $66.44                         New
# 713          43   $69.49                         New
# 714          44   $72.01                         New
# 715          45   $74.84                         New
# 716          46   $74.98                         New
# 717          47   $78.00                         New
# 718          48   $78.92                         New
# 719          49   $79.00                         New
# 720          50   $79.00                         New
# 721          51   $54.99  Used\n         - Very Good
# 722          52   $56.00                         New
# 723          53   $79.99                         New
# 724          54   $79.99                         New
# 725          55   $81.16                         New
# 726          56   $81.16                         New
# 727          57   $86.03                         New
# 728          58   $99.99                         New
# 729          59  $129.99                         New
# 730          60   $65.95                         New
# 731          61   $79.99                         New
# 732          62   $99.99                         New
# 733          63   $99.99                         New
# 742           2   $55.84                         New
#
#                                                 Seller  \
# 0                                             ABossler
# 1                                    Veeds Electronics
# 2                             Springfield Distribution
# 3                                             Acebeach
# 4                               Ocean Reef Electronics
# 5                                       CherieAndDavid
# 7                                        Tech for Less
# 8                                              Adorama
# 9                                   NEW DJ CORPORATION
# 10                                            RareItem
# 11                          Bright Spot (We record SN)
# 12                                   Always Innovating
# 13                                       games-surplus
# 14                                       i-Deals Store
# 15                                           Maze Tech
# 16                                         ParlorBooks
# 17   L&Y Business (NO ANY REBATE | SERIAL NUM RECOR...
# 18                         Deep_Discount_Entertainment
# 20                                            MallStop
# 21                            Springfield Distribution
# 22                              Amazing Bookshelf, Llc
# 23                                            Acebeach
# 25                          Terrace Mall (SN Recorded)
# 26                                              ZDeals
# 27                                             Adorama
# 28                                     American deals!
# 29                                           GAMEZLAND
# 30                                        Deal Targets
# 31                                  NEW DJ CORPORATION
# 32                                   Always Innovating
# ..                                                 ...
# 705                                         ComegaCity
# 706                                      i-Deals Store
# 707                                    MiamiVideoGames
# 708                                          POPnGAMES
# 709                                 JADD ENTERTAINMENT
# 710                                       PORTABLE GUY
# 711                                   Tri State Camera
# 712                                     It's Your Turn
# 713                                           JM PRIME
# 714                                    TheFactoryDepot
# 715                                         SpaceBound
# 716                                         IPC-STORE✅
# 717                                       BooksandSoft
# 718                                        VirVentures
# 719                                   Dillon Bookstore
# 720                                           Acebeach
# 721                                          GameAve11
# 722                                        GameforceLA
# 723                                     Spokane Supply
# 724                                      DigitalWorld1
# 725          IBD - International Brand Distribution US
# 726                                   GLOBAL AGENCY GP
# 727                                       Deal Outlets
# 728           Tek Star (SIGNATURE REQUIRED 4 Delivery)
# 729                                            HITO Me
# 730                                     games_for_sale
# 731                                      DigitalWorld1
# 732                                      DigitalWorld1
# 733                                      DigitalWorld1
# 742                            Amazon.com Services LLC
#
#                                            ProductName        Brand  \
# 0     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 1     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 2     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 3     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 4     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 5     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 7     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 8     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 9     Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 10    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 11    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 12    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 13    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 14    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 15    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 16    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 17    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 18    Nintendo Switch with Gray Joy‑Con - HAC-001(-01)  by Nintendo
# 20   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 21   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 22   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 23   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 25   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 26   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 27   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 28   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 29   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 30   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 31   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# 32   Nintendo Switch with Neon Blue and Neon Red Jo...  by Nintendo
# ..                                                 ...          ...
# 705              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 706              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 707              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 708              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 709              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 710              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 711              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 712              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 713              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 714              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 715              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 716              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 717              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 718              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 719              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 720              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 721              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 722              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 723              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 724              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 725              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 726              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 727              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 728              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 729              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 730              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 731              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 732              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 733              Mario Kart 8 Deluxe - Nintendo Switch  by Nintendo
# 742                                Mario Kart 8 Deluxe  by Nintendo
#
#     Feature1Name               Feature1 Feature2Name  \
# 0         Style:                Console       Color:
# 1         Style:                Console       Color:
# 2         Style:                Console       Color:
# 3         Style:                Console       Color:
# 4         Style:                Console       Color:
# 5         Style:                Console       Color:
# 7         Style:                Console       Color:
# 8         Style:                Console       Color:
# 9         Style:                Console       Color:
# 10        Style:                Console       Color:
# 11        Style:                Console       Color:
# 12        Style:                Console       Color:
# 13        Style:                Console       Color:
# 14        Style:                Console       Color:
# 15        Style:                Console       Color:
# 16        Style:                Console       Color:
# 17        Style:                Console       Color:
# 18        Style:                Console       Color:
# 20        Style:                Console       Color:
# 21        Style:                Console       Color:
# 22        Style:                Console       Color:
# 23        Style:                Console       Color:
# 25        Style:                Console       Color:
# 26        Style:                Console       Color:
# 27        Style:                Console       Color:
# 28        Style:                Console       Color:
# 29        Style:                Console       Color:
# 30        Style:                Console       Color:
# 31        Style:                Console       Color:
# 32        Style:                Console       Color:
# ..           ...                    ...          ...
# 705    Platform:        Nintendo Switch     Edition:
# 706    Platform:        Nintendo Switch     Edition:
# 707    Platform:        Nintendo Switch     Edition:
# 708    Platform:        Nintendo Switch     Edition:
# 709    Platform:        Nintendo Switch     Edition:
# 710    Platform:        Nintendo Switch     Edition:
# 711    Platform:        Nintendo Switch     Edition:
# 712    Platform:        Nintendo Switch     Edition:
# 713    Platform:        Nintendo Switch     Edition:
# 714    Platform:        Nintendo Switch     Edition:
# 715    Platform:        Nintendo Switch     Edition:
# 716    Platform:        Nintendo Switch     Edition:
# 717    Platform:        Nintendo Switch     Edition:
# 718    Platform:        Nintendo Switch     Edition:
# 719    Platform:        Nintendo Switch     Edition:
# 720    Platform:        Nintendo Switch     Edition:
# 721    Platform:        Nintendo Switch     Edition:
# 722    Platform:        Nintendo Switch     Edition:
# 723    Platform:        Nintendo Switch     Edition:
# 724    Platform:        Nintendo Switch     Edition:
# 725    Platform:        Nintendo Switch     Edition:
# 726    Platform:        Nintendo Switch     Edition:
# 727    Platform:        Nintendo Switch     Edition:
# 728    Platform:        Nintendo Switch     Edition:
# 729    Platform:        Nintendo Switch     Edition:
# 730    Platform:        Nintendo Switch     Edition:
# 731    Platform:        Nintendo Switch     Edition:
# 732    Platform:        Nintendo Switch     Edition:
# 733    Platform:        Nintendo Switch     Edition:
# 742    Platform:  Lowest offer for each     Edition:
#
#                            Feature2
# 0                 Gray HAC-001(-01)
# 1                 Gray HAC-001(-01)
# 2                 Gray HAC-001(-01)
# 3                 Gray HAC-001(-01)
# 4                 Gray HAC-001(-01)
# 5                 Gray HAC-001(-01)
# 7                 Gray HAC-001(-01)
# 8                 Gray HAC-001(-01)
# 9                 Gray HAC-001(-01)
# 10                Gray HAC-001(-01)
# 11                Gray HAC-001(-01)
# 12                Gray HAC-001(-01)
# 13                Gray HAC-001(-01)
# 14                Gray HAC-001(-01)
# 15                Gray HAC-001(-01)
# 16                Gray HAC-001(-01)
# 17                Gray HAC-001(-01)
# 18                Gray HAC-001(-01)
# 20   Neon Blue and Red HAC-001(-01)
# 21   Neon Blue and Red HAC-001(-01)
# 22   Neon Blue and Red HAC-001(-01)
# 23   Neon Blue and Red HAC-001(-01)
# 25   Neon Blue and Red HAC-001(-01)
# 26   Neon Blue and Red HAC-001(-01)
# 27   Neon Blue and Red HAC-001(-01)
# 28   Neon Blue and Red HAC-001(-01)
# 29   Neon Blue and Red HAC-001(-01)
# 30   Neon Blue and Red HAC-001(-01)
# 31   Neon Blue and Red HAC-001(-01)
# 32   Neon Blue and Red HAC-001(-01)
# ..                              ...
# 705                        Standard
# 706                        Standard
# 707                        Standard
# 708                        Standard
# 709                        Standard
# 710                        Standard
# 711                        Standard
# 712                        Standard
# 713                        Standard
# 714                        Standard
# 715                        Standard
# 716                        Standard
# 717                        Standard
# 718                        Standard
# 719                        Standard
# 720                        Standard
# 721                        Standard
# 722                        Standard
# 723                        Standard
# 724                        Standard
# 725                        Standard
# 726                        Standard
# 727                        Standard
# 728                        Standard
# 729                        Standard
# 730                        Standard
# 731                        Standard
# 732                        Standard
# 733                        Standard
# 742           Lowest offer for each
#
# [324 rows x 10 columns]
